# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
p_cle_clo = 0.5 #prob of sun|cloud
p_cle_cle = 0.9 #prob of sun|sun

# %% [markdown]
# ** 0 is cloud, 1 sun **

# %%
def jump_prob(theta):
    if (theta == 0):
        theta_i = np.random.binomial(1, p_cle_clo)
    if (theta == 1):
        theta_i = np.random.binomial(1, p_cle_cle)
    return theta_i

def loop(n = 10000, initial_guess = 0):
    x = [initial_guess]
    sunny_days = np.zeros((2, n))
    total_sunny_days = 0
    for i in range(n):
        step = jump_prob(x[i])
        x.append(step)
        if (step == 1): 
            total_sunny_days += 1
            sunny_days[0, i] = total_sunny_days
            sunny_days[1, i] = i+1
    return x, sunny_days

# %%
n = 10000
cloud_sunny = 0 #today is cloudy
distribution_values, n_sunny = loop(n, cloud_sunny)
fig, (fig1, fig2) = plt.subplots(ncols=2, figsize = (15, 4))
fig1.hist(distribution_values , density = False)
fig1.grid(visible=True)
print('number of sunny days ', n_sunny[0, n-1], 'that is', n_sunny[0, n-1]/n * 100, '%')

x_ax = np.linspace(0, len(distribution_values), n)
fig2.plot(x_ax, n_sunny[0, :]/n_sunny[1, :])
fig2.grid(visible = True)
fig2.set(xlabel = 'number of days passed', ylabel = 'percentage of sunny days')
# Out:
# number of sunny days  8370.0 that is 83.7 %
# /tmp/ipykernel_3339/850464690.py:10: RuntimeWarning: invalid value encountered in divide
#   fig2.plot(x_ax, n_sunny[0, :]/n_sunny[1, :])
# [Text(0.5, 0, 'number of days passed'),
#  Text(0, 0.5, 'percentage of sunny days')]

# %%
plt.hist(n_sunny[0, :]/n_sunny[1, :], 100)
# Out:
# /tmp/ipykernel_3339/1330074626.py:1: RuntimeWarning: invalid value encountered in divide
#   plt.hist(n_sunny[0, :]/n_sunny[1, :], 100)
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 3.000e+00, 2.631e+03, 2.066e+03, 2.528e+03,
#         6.410e+02, 1.930e+02, 5.400e+01, 4.800e+01, 3.900e+01, 2.100e+01,
#         2.400e+01, 1.700e+01, 7.000e+00, 3.000e+00, 5.000e+00, 6.000e+00,
#         6.000e+00, 8.000e+00, 1.000e+01, 1.700e+01, 1.600e+01, 1.400e+01,
#         5.000e+00, 1.000e+00, 1.000e+00, 2.000e+00]),
#  array([0.5       , 0.50447368, 0.50894737, 0.51342105, 0.51789474,
#         0.52236842, 0.52684211, 0.53131579, 0.53578947, 0.54026316,
#         0.54473684, 0.54921053, 0.55368421, 0.55815789, 0.56263158,
#         0.56710526, 0.57157895, 0.57605263, 0.58052632, 0.585     ,
#         0.58947368, 0.59394737, 0.59842105, 0.60289474, 0.60736842,
#         0.61184211, 0.61631579, 0.62078947, 0.62526316, 0.62973684,
#         0.63421053, 0.63868421, 0.64315789, 0.64763158, 0.65210526,
#         0.65657895, 0.66105263, 0.66552632, 0.67      , 0.67447368,
#         0.67894737, 0.68342105, 0.68789474, 0.69236842, 0.69684211,
#         0.70131579, 0.70578947, 0.71026316, 0.71473684, 0.71921053,
#         0.72368421, 0.72815789, 0.73263158, 0.73710526, 0.74157895,
#         0.74605263, 0.75052632, 0.755     , 0.75947368, 0.76394737,
#         0.76842105, 0.77289474, 0.77736842, 0.78184211, 0.78631579,
#         0.79078947, 0.79526316, 0.79973684, 0.80421053, 0.80868421,
#         0.81315789, 0.81763158, 0.82210526, 0.82657895, 0.83105263,
#         0.83552632, 0.84      , 0.84447368, 0.84894737, 0.85342105,
#         0.85789474, 0.86236842, 0.86684211, 0.87131579, 0.87578947,
#         0.88026316, 0.88473684, 0.88921053, 0.89368421, 0.89815789,
#         0.90263158, 0.90710526, 0.91157895, 0.91605263, 0.92052632,
#         0.925     , 0.92947368, 0.93394737, 0.93842105, 0.94289474,
#         0.94736842]),
#  <BarContainer object of 100 artists>)
