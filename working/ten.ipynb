# %%
import numpy as np
import scipy

# %%
p_cle_clo = 0.5
p_cle_cle = 0.9
p_clo_clo = 0.5
p_clo_cle = 0.1

# %%
def jump_prob(theta):
    theta_i = 0
    if (theta == 0):
        theta_i = np.random.binomial(1, 0.5)
    if (theta == 1):
        theta_i = np.random.binomial(1, 0.9)
